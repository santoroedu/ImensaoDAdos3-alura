# %% [markdown]
# <a href="https://colab.research.google.com/github/santoroedu/ImensaoDAdos3-alura/blob/main/Aula4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Aula 04: Merge de dados e análise de resultados

# %%
# Importando os arquivos de dados ( base de dados - csv )
import pandas as pd
import numpy as np

# Grafico utilizando Seaborn e MatPlotLib
import seaborn as sns
import matplotlib.pyplot as plt

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados,compression='zip')

# Retirando o hifem da coluna cabeçalho
dados.columns = dados.columns.str.replace('-','')

# Renomeando cabeçalho da coluna droga para composto
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)

# Exibe os tabela dados
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 877 columns]

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultados.drop('id',axis=1).sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.drop('id',axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id',axis=1).sum(axis=1)

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)

# %%
dados_resultados
# Out:
#                  id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0      id_000644bb2                            0  ...      1       True
# 1      id_000779bfc                            0  ...      0      False
# 2      id_000a6266a                            0  ...      3       True
# 3      id_0015fd391                            0  ...      0      False
# 4      id_001626bd3                            0  ...      1       True
# ...             ...                          ...  ...    ...        ...
# 23809  id_fffb1ceed                            0  ...      1       True
# 23810  id_fffb70c0c                            0  ...      1       True
# 23811  id_fffc1c3f4                            0  ...      0      False
# 23812  id_fffcb9e7c                            0  ...      1       True
# 23813  id_ffffdd77b                            0  ...      0      False
#
# [23814 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa','ativo_moa']], on='id')
dados_combinados
# Out:
#                  id    tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 0      id_000644bb2     com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1      id_000779bfc     com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2      id_000a6266a     com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3      id_0015fd391     com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4      id_001626bd3     com_droga     72   D2  ... -0.3786  0.7125      1       True
# ...             ...           ...    ...  ...  ...     ...     ...    ...        ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.5258  0.4680      1       True
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2715  0.3689      1       True
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.6656  0.3808      0      False
# 23812  id_fffcb9e7c     com_droga     24   D1  ... -0.6290  0.0740      1       True
# 23813  id_ffffdd77b     com_droga     72   D1  ... -2.1500 -4.2520      0      False
#
# [23814 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
sns.set()
#sns.boxplot(data= dados_combinados, y='g0', x='composto')
plt.figure(figsize=(12,8))
sns.boxplot(data= dados_combinados.query('composto in @composto_principal'), y='g0', x='composto', hue='ativo_moa')

# %% [markdown]
# ### D E S A F I O S

# %%
### Desafio 01: Encontrar o top 10, das ações do MOA (inibidor, agonista...)
contagem_moa2 = pd.DataFrame(list(zip(contagem_moa[2:].index,([col.split('_')[-1] for col in contagem_moa[2:].index]),contagem_moa[2:].values)))
contagem_moa2.columns =['tipo_acao_moa', 'acao_moa', 'soma_moa']
contagem_moa2
# Out:
#                                   tipo_acao_moa    acao_moa  soma_moa
# 0                                nfkb_inhibitor   inhibitor       832
# 1                          proteasome_inhibitor   inhibitor       726
# 2                      cyclooxygenase_inhibitor   inhibitor       435
# 3                  dopamine_receptor_antagonist  antagonist       424
# 4                 serotonin_receptor_antagonist  antagonist       404
# ..                                          ...         ...       ...
# 201                                     steroid     steroid         6
# 202                  nicotinic_receptor_agonist     agonist         6
# 203                          elastase_inhibitor   inhibitor         6
# 204                             erbb2_inhibitor   inhibitor         1
# 205  atp-sensitive_potassium_channel_antagonist  antagonist         1
#
# [206 rows x 3 columns]

# %%
dados_moa = contagem_moa2.groupby(['acao_moa']).sum()
top10_acao_moa = dados_moa.sort_values(by=['soma_moa'], ascending=False)[0:10]
top10_acao_moa
# Out:
#                    soma_moa
# acao_moa
# inhibitor              9693
# antagonist             3449
# agonist                2330
# blocker                 323
# agent                   150
# activator               115
# local                    80
# antioxidant              73
# anti-inflammatory        73
# immunosuppressant        73

# %%
### Desafio 02: Criar a coluna eh_controle para quando na linha tratamento == com_controle
dados_combinados['eh_controle'] = (dados_combinados['tratamento'] == 'com_controle')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c99  n_moa  ativo_moa  eh_controle
# 0  id_000644bb2  com_droga     24   D1  ...  0.4176      1       True        False
# 1  id_000779bfc  com_droga     72   D1  ...  0.7371      0      False        False
# 2  id_000a6266a  com_droga     48   D1  ...  0.6931      3       True        False
# 3  id_0015fd391  com_droga     48   D1  ... -0.8154      0      False        False
# 4  id_001626bd3  com_droga     72   D2  ...  0.7125      1       True        False
#
# [5 rows x 880 columns]

# %%
### Desafio 03: Criar três colunas para indicar o tempo 24, 48, 72
dados_combinados['tempo_24'] = (dados_combinados['tempo'] == 24)
dados_combinados['tempo_48'] = (dados_combinados['tempo'] == 48)
dados_combinados['tempo_72'] = (dados_combinados['tempo'] == 72)
dados_combinados.head()
# Out:
#              id tratamento  tempo  ... tempo_24 tempo_48  tempo_72
# 0  id_000644bb2  com_droga     24  ...     True    False     False
# 1  id_000779bfc  com_droga     72  ...    False    False      True
# 2  id_000a6266a  com_droga     48  ...    False     True     False
# 3  id_0015fd391  com_droga     48  ...    False     True     False
# 4  id_001626bd3  com_droga     72  ...    False    False      True
#
# [5 rows x 883 columns]

# %%
### Desafio 04: Estudar sobre combinações de DF https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %%
### Desafio 05: Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (Escolher uma droga e comparar com controle)
composto = dados_combinados[dados_combinados['composto']=='8b87a7a83']
controle = dados_combinados[dados_combinados['tratamento']=='com_controle']

fig, axs = plt.subplots(1,2,figsize=(20,8))

sns.boxplot(data=composto,y='g8', x='tempo', hue='dose',ax=axs[0])
axs[0].set_title('Composto 8b87a7a83')
sns.boxplot(data=controle,y='g8', x='tempo', hue='dose',ax=axs[1])
axs[1].set_title('Controle')
# Out:
# Text(0.5, 1.0, 'Controle')

# %%
### Desafio 06: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA
#pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'])
dados_descoberto = pd.merge(dados_combinados[['composto','n_moa']].query('n_moa >= 1'),dados_combinados[['composto','n_moa']].query('n_moa == 0'), on = 'composto')
if dados_descoberto.empty:
    print('Nenhum experimento, ativa ou não ativa algum MOA')
# Out:
# Nenhum experimento, ativa ou não ativa algum MOA

# %%
### Desafio 07: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa MOAs diferentes
#dados_mos_dif = pd.merge(dados_resultados, dados[['id','tratamento','tempo','dose','composto']], on = 'id')
#((dados_mos_dif.query('n_moa > 1').drop('id',axis=1)).drop('n_moa',axis=1)).drop('ativo_moa',axis=1)

## Deu ruim!! não consegui

# %%
### Desafio 08: Resumo do que você aprendeu com os dados
# Utilizar o .drop()
# Utilizar o .sort_values()
# Utilizar o .select_dtypes()
# Utilizar o .merge()
#
